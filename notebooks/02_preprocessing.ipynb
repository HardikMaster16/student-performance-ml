# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    ConfusionMatrixDisplay
)
import matplotlib.pyplot as plt

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("../data/raw/student-mat.csv", sep=";")

# %%
df["performance"] = (df["G3"] >= 10).astype(int)

# %%
features = [
    "school",
    "sex",
    "age",
    "address",
    "famsize",
    "Pstatus",
    "Medu",
    "Fedu",
    "Mjob",
    "Fjob",
    "reason",
    "guardian",
    "traveltime",
    "studytime",
    "failures",
    "schoolsup",
    "famsup",
    "paid",
    "activities",
    "nursery",
    "higher",
    "internet",
    "romantic",
    "famrel",
    "freetime",
    "goout",
    "Dalc",
    "Walc",
    "health",
    "absences"
]

# %%
X = df[features]
y = df["performance"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 316
# Testing samples: 79

# %%
#proportion of class
print("Training class distribution:")
print(y_train.value_counts(normalize=True))

print("\nTesting class distribution:")
print(y_test.value_counts(normalize=True))
# Out:
# Training class distribution:
# performance
# 1    0.670886
# 0    0.329114
# Name: proportion, dtype: float64
#
# Testing class distribution:
# performance
# 1    0.670886
# 0    0.329114
# Name: proportion, dtype: float64

# %%
numeric_features = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

categorical_features = X.select_dtypes(
    include=["object"]
).columns.tolist()

# %%
print("Numerical features:")
print(numeric_features)

print("\nCategorical features:")
print(categorical_features)
# Out:
# Numerical features:
# ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences']
#
# Categorical features:
# ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']

# %%
numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ]
)

# %%
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        (
            "onehot",
            OneHotEncoder(
                handle_unknown="ignore"
            )
        )
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            numeric_transformer,
            numeric_features
        ),
        (
            "cat",
            categorical_transformer,
            categorical_features
        )
    ]
)

# %%
X_train_processed = preprocessor.fit_transform(X_train)

# %%
X_test_processed = preprocessor.transform(X_test)

# %%
print("Original training shape:", X_train.shape)
print("Processed training shape:", X_train_processed.shape)
# Out:
# Original training shape: (316, 30)
# Processed training shape: (316, 56)

# %%
type(X_train_processed)
# Out:
# numpy.ndarray

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

# %%
ml_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", model)
    ]
)

# %%
ml_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=42))])

# %%
y_pred = ml_pipeline.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([0, 0, 1, 1, 1, 1, 1, 0, 1, 1])

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6582278481012658

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[ 9 17]
#  [10 43]]

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    display_labels=["At Risk", "Good"]
)

plt.title("Confusion Matrix — Logistic Regression")
plt.show()

# %%
precision = precision_score(y_test, y_pred)

print("Precision:", precision)
# Out:
# Precision: 0.7166666666666667

# %%
recall = recall_score(y_test, y_pred)

print("Recall:", recall)
# Out:
# Recall: 0.8113207547169812

# %%
f1 = f1_score(y_test, y_pred)

print("F1-score:", f1)
# Out:
# F1-score: 0.7610619469026548

# %%
print(classification_report(
    y_test,
    y_pred,
    target_names=["At Risk", "Good"]
))
# Out:
#               precision    recall  f1-score   support
#
#      At Risk       0.47      0.35      0.40        26
#         Good       0.72      0.81      0.76        53
#
#     accuracy                           0.66        79
#    macro avg       0.60      0.58      0.58        79
# weighted avg       0.64      0.66      0.64        79

# %%
y_prob = ml_pipeline.predict_proba(X_test)[:, 1]

# %%
roc_auc = roc_auc_score(y_test, y_prob)

print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.588534107402032

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    results = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1": f1_score(y_test, y_pred),
        "ROC-AUC": roc_auc_score(y_test, y_prob)
    }

    return results

# %%
results = evaluate_model(
    ml_pipeline,
    X_test,
    y_test
)

results
# Out:
# {'Accuracy': 0.6582278481012658,
#  'Precision': 0.7166666666666667,
#  'Recall': 0.8113207547169812,
#  'F1': 0.7610619469026548,
#  'ROC-AUC': 0.588534107402032}

# %%
results_df = pd.DataFrame(
    [results],
    index=["Logistic Regression"]
)

results_df
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Logistic Regression  0.658228   0.716667  0.811321  0.761062  0.588534

# %%
from sklearn.dummy import DummyClassifier

# %%
dummy_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            DummyClassifier(
                strategy="most_frequent"
            )
        )
    ]
)

# %%
dummy_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model', DummyClassifier(strategy='most_frequent'))])

# %%
dummy_results = evaluate_model(
    dummy_model,
    X_test,
    y_test
)

dummy_results
# Out:
# {'Accuracy': 0.6708860759493671,
#  'Precision': 0.6708860759493671,
#  'Recall': 1.0,
#  'F1': 0.803030303030303,
#  'ROC-AUC': 0.5}

# %%
comparison = pd.DataFrame(
    [
        dummy_results,
        results
    ],
    index=[
        "Dummy Baseline",
        "Logistic Regression"
    ]
)

comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Dummy Baseline       0.670886   0.670886  1.000000  0.803030  0.500000
# Logistic Regression  0.658228   0.716667  0.811321  0.761062  0.588534

# %%
import xgboost
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)

print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (316, 30)
# X_test: (79, 30)
# y_train: (316,)
# y_test: (79,)

# %%
logistic_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            LogisticRegression(
                max_iter=1000,
                random_state=42
            )
        )
    ]
)

# %%
logistic_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=42))])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            RandomForestClassifier(
                n_estimators=300,
                random_state=42
            )
        )
    ]
)

# %%
random_forest_pipeline.fit(
    X_train,
    y_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model',
#                  RandomForestClassifier(n_estimators=300, random_state=42))])

# %%
rf_predictions = random_forest_pipeline.predict(X_test)

# %%
rf_probabilities = random_forest_pipeline.predict_proba(X_test)[:, 1]

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    results = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1": f1_score(y_test, y_pred),
        "ROC-AUC": roc_auc_score(y_test, y_prob)
    }

    return results

# %%
rf_results = evaluate_model(
    random_forest_pipeline,
    X_test,
    y_test
)

rf_results
# Out:
# {'Accuracy': 0.6708860759493671,
#  'Precision': 0.7076923076923077,
#  'Recall': 0.8679245283018868,
#  'F1': 0.7796610169491526,
#  'ROC-AUC': 0.63933236574746}

# %%
from xgboost import XGBClassifier

# %%
xgb_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            XGBClassifier(
                n_estimators=300,
                max_depth=4,
                learning_rate=0.05,
                random_state=42,
                eval_metric="logloss"
            )
        )
    ]
)

# %%
xgb_pipeline.fit(
    X_train,
    y_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_freq...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
xgb_predictions = xgb_pipeline.predict(X_test)

# %%
xgb_probabilities = xgb_pipeline.predict_proba(X_test)[:, 1]

# %%
xgb_results = evaluate_model(
    xgb_pipeline,
    X_test,
    y_test
)

xgb_results
# Out:
# {'Accuracy': 0.6329113924050633,
#  'Precision': 0.7142857142857143,
#  'Recall': 0.7547169811320755,
#  'F1': 0.7339449541284404,
#  'ROC-AUC': 0.5653120464441219}

# %%
logistic_results = evaluate_model(
    logistic_pipeline,
    X_test,
    y_test
)

logistic_results
# Out:
# {'Accuracy': 0.6582278481012658,
#  'Precision': 0.7166666666666667,
#  'Recall': 0.8113207547169812,
#  'F1': 0.7610619469026548,
#  'ROC-AUC': 0.588534107402032}

# %%
model_comparison = pd.DataFrame(
    [
        logistic_results,
        rf_results,
        xgb_results
    ],
    index=[
        "Logistic Regression",
        "Random Forest",
        "XGBoost"
    ]
)

model_comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Logistic Regression  0.658228   0.716667  0.811321  0.761062  0.588534
# Random Forest        0.670886   0.707692  0.867925  0.779661  0.639332
# XGBoost              0.632911   0.714286  0.754717  0.733945  0.565312

# %%
model_comparison = pd.DataFrame(
    [
        dummy_results,
        logistic_results,
        rf_results,
        xgb_results
    ],
    index=[
        "Dummy Baseline",
        "Logistic Regression",
        "Random Forest",
        "XGBoost"
    ]
)

model_comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Dummy Baseline       0.670886   0.670886  1.000000  0.803030  0.500000
# Logistic Regression  0.658228   0.716667  0.811321  0.761062  0.588534
# Random Forest        0.670886   0.707692  0.867925  0.779661  0.639332
# XGBoost              0.632911   0.714286  0.754717  0.733945  0.565312

# %%
df["performance"] = (df["G3"] >= 10).astype(int)

# %%
df["performance"] = (df["G3"] < 10).astype(int)

# %%
df["performance"].value_counts()
# Out:
# performance
# 0    265
# 1    130
# Name: count, dtype: int64

# %%
X = df[features]
y = df["performance"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
logistic_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            LogisticRegression(
                max_iter=1000,
                random_state=42
            )
        )
    ]
)

# %%
random_forest_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            RandomForestClassifier(
                n_estimators=300,
                random_state=42
            )
        )
    ]
)

# %%
xgb_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            XGBClassifier(
                n_estimators=300,
                max_depth=4,
                learning_rate=0.05,
                random_state=42,
                eval_metric="logloss"
            )
        )
    ]
)

# %%
logistic_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=42))])

# %%
random_forest_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model',
#                  RandomForestClassifier(n_estimators=300, random_state=42))])

# %%
xgb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_freq...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
logistic_results = evaluate_model(
    logistic_pipeline,
    X_test,
    y_test
)

# %%
rf_results = evaluate_model(
    random_forest_pipeline,
    X_test,
    y_test
)

# %%
xgb_results = evaluate_model(
    xgb_pipeline,
    X_test,
    y_test
)

# %%
model_comparison = pd.DataFrame(
    [
        logistic_results,
        rf_results,
        xgb_results
    ],
    index=[
        "Logistic Regression",
        "Random Forest",
        "XGBoost"
    ]
)

model_comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Logistic Regression  0.696203   0.571429  0.307692  0.400000  0.714804
# Random Forest        0.708861   0.615385  0.307692  0.410256  0.694485
# XGBoost              0.708861   0.578947  0.423077  0.488889  0.702467

# %%
model_comparison.to_csv(
    "../data/processed/model_comparison.csv"
)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
xgb_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            XGBClassifier(
                random_state=42,
                eval_metric="logloss"
            )
        )
    ]
)

# %%
param_distributions = {
    "model__n_estimators": [100, 200, 300, 500],
    "model__max_depth": [2, 3, 4, 5, 6],
    "model__learning_rate": [0.01, 0.03, 0.05, 0.1],
    "model__subsample": [0.7, 0.8, 0.9, 1.0],
    "model__colsample_bytree": [0.7, 0.8, 0.9, 1.0]
}

# %%
from sklearn.model_selection import StratifiedKFold

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
random_search = RandomizedSearchCV(
    estimator=xgb_pipeline,
    param_distributions=param_distributions,
    n_iter=20,
    scoring="f1",
    cv=cv,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

# %%
random_search.fit(
    X_train,
    y_train
)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['age',
#                                                                                 'Medu',
#                                                                                 'Fedu',
#                                                                                 'traveltime',
#                                                                                 'studytime',
#                                                                                 'failures',
#                                                                                 'famrel',
#                                                                                 'freetime',
#                                                                                 'goout',
#                                                                                 'Dalc',
#                                                                                 'Walc',...
#                                                             multi_strategy=None,
#                                                             n_estimators=None,
#                                                             n_jobs=None,
#                                                             num_parallel_tree=None, ...))]),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'model__colsample_bytree': [0.7, 0.8,
#                                                                     0.9, 1.0],
#                                         'model__learning_rate': [0.01, 0.03,
#                                                                  0.05, 0.1],
#                                         'model__max_depth': [2, 3, 4, 5, 6],
#                                         'model__n_estimators': [100, 200, 300,
#                                                                 500],
#                                         'model__subsample': [0.7, 0.8, 0.9,
#                                                              1.0]},
#                    random_state=42, scoring='f1', verbose=1)

# %%
random_search.best_params_
# Out:
# {'model__subsample': 0.7,
#  'model__n_estimators': 300,
#  'model__max_depth': 4,
#  'model__learning_rate': 0.1,
#  'model__colsample_bytree': 1.0}

# %%
random_search.best_score_
# Out:
# 0.4365587651268218

# %%
best_xgb_model = random_search.best_estimator_

# %%
tuned_results = evaluate_model(
    best_xgb_model,
    X_test,
    y_test
)

tuned_results
# Out:
# {'Accuracy': 0.759493670886076,
#  'Precision': 0.6842105263157895,
#  'Recall': 0.5,
#  'F1': 0.5777777777777777,
#  'ROC-AUC': 0.7438316400580551}

# %%
comparison = pd.DataFrame(
    [
        xgb_results,
        tuned_results
    ],
    index=[
        "Original XGBoost",
        "Tuned XGBoost"
    ]
)

comparison
# Out:
#                   Accuracy  Precision    Recall        F1   ROC-AUC
# Original XGBoost  0.708861   0.578947  0.423077  0.488889  0.702467
# Tuned XGBoost     0.759494   0.684211  0.500000  0.577778  0.743832

# %%
final_comparison = pd.DataFrame(
    [
        dummy_results,
        logistic_results,
        rf_results,
        xgb_results,
        tuned_results
    ],
    index=[
        "Dummy Baseline",
        "Logistic Regression",
        "Random Forest",
        "Original XGBoost",
        "Tuned XGBoost"
    ]
)

final_comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Dummy Baseline       0.670886   0.670886  1.000000  0.803030  0.500000
# Logistic Regression  0.696203   0.571429  0.307692  0.400000  0.714804
# Random Forest        0.708861   0.615385  0.307692  0.410256  0.694485
# Original XGBoost     0.708861   0.578947  0.423077  0.488889  0.702467
# Tuned XGBoost        0.759494   0.684211  0.500000  0.577778  0.743832

# %%
final_comparison["F1"].plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Model F1-Score Comparison")
plt.xlabel("Model")
plt.ylabel("F1 Score")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
y_pred_tuned = best_xgb_model.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred_tuned,
    display_labels=["Good", "At Risk"]
)

plt.title("Tuned XGBoost — Confusion Matrix")
plt.show()

# %%
print(
    classification_report(
        y_test,
        y_pred_tuned,
        target_names=["Good", "At Risk"]
    )
)
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.78      0.89      0.83        53
#      At Risk       0.68      0.50      0.58        26
#
#     accuracy                           0.76        79
#    macro avg       0.73      0.69      0.70        79
# weighted avg       0.75      0.76      0.75        79

# %%
cv_results = pd.DataFrame(
    random_search.cv_results_
)

# %%
cv_results[
    [
        "mean_test_score",
        "std_test_score",
        "rank_test_score",
        "params"
    ]
].sort_values(
    "rank_test_score"
).head(10)
# Out:
#     mean_test_score  std_test_score  rank_test_score  \
# 0          0.436559        0.082226                1
# 16         0.429512        0.071093                2
# 14         0.429133        0.097422                3
# 18         0.428095        0.112540                4
# 6          0.424371        0.094505                5
# 17         0.424340        0.072501                6
# 3          0.420227        0.088362                7
# 15         0.419885        0.057495                8
# 11         0.415108        0.100886                9
# 7          0.414553        0.085950               10
#
#                                                params
# 0   {'model__subsample': 0.7, 'model__n_estimators...
# 16  {'model__subsample': 1.0, 'model__n_estimators...
# 14  {'model__subsample': 0.9, 'model__n_estimators...
# 18  {'model__subsample': 0.9, 'model__n_estimators...
# 6   {'model__subsample': 1.0, 'model__n_estimators...
# 17  {'model__subsample': 0.8, 'model__n_estimators...
# 3   {'model__subsample': 0.9, 'model__n_estimators...
# 15  {'model__subsample': 0.9, 'model__n_estimators...
# 11  {'model__subsample': 0.7, 'model__n_estimators...
# 7   {'model__subsample': 0.7, 'model__n_estimators...

# %%
cv_results.to_csv(
    "../data/processed/xgboost_tuning_results.csv",
    index=False
)

# %%
final_comparison.to_csv(
    "../data/processed/final_model_comparison.csv"
)

# %%
final_comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Dummy Baseline       0.670886   0.670886  1.000000  0.803030  0.500000
# Logistic Regression  0.696203   0.571429  0.307692  0.400000  0.714804
# Random Forest        0.708861   0.615385  0.307692  0.410256  0.694485
# Original XGBoost     0.708861   0.578947  0.423077  0.488889  0.702467
# Tuned XGBoost        0.759494   0.684211  0.500000  0.577778  0.743832

# %%
random_search.best_params_
# Out:
# {'model__subsample': 0.7,
#  'model__n_estimators': 300,
#  'model__max_depth': 4,
#  'model__learning_rate': 0.1,
#  'model__colsample_bytree': 1.0}

# %%
random_search.best_score_
# Out:
# 0.4365587651268218

# %%
print(
    classification_report(
        y_test,
        y_pred_tuned,
        target_names=["Good", "At Risk"]
    )
)
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.78      0.89      0.83        53
#      At Risk       0.68      0.50      0.58        26
#
#     accuracy                           0.76        79
#    macro avg       0.73      0.69      0.70        79
# weighted avg       0.75      0.76      0.75        79

# %%
df = pd.read_csv("../data/raw/student-mat.csv", sep=";")

df["performance"] = (df["G3"] < 10).astype(int)

print(df["performance"].value_counts())
print()
print(df["performance"].value_counts(normalize=True))
# Out:
# performance
# 0    265
# 1    130
# Name: count, dtype: int64
#
# performance
# 0    0.670886
# 1    0.329114
# Name: proportion, dtype: float64

# %%
print("G3 = 5:", int(5 < 10))
print("G3 = 10:", int(10 < 10))
print("G3 = 15:", int(15 < 10))
# Out:
# G3 = 5: 1
# G3 = 10: 0
# G3 = 15: 0

# %%
pd.crosstab(
    df["performance"],
    pd.cut(
        df["G3"],
        bins=[-1, 9, 20],
        labels=["At Risk", "Good"]
    )
)
# Out:
# G3           At Risk  Good
# performance
# 0                  0   265
# 1                130     0

# %%
X = df[features]
y = df["performance"]

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)

print("\nTarget distribution:")
print(y.value_counts())
# Out:
# X shape: (395, 30)
# y shape: (395,)
#
# Target distribution:
# performance
# 0    265
# 1    130
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("Training:")
print(y_train.value_counts())

print("\nTesting:")
print(y_test.value_counts())
# Out:
# Training:
# performance
# 0    212
# 1    104
# Name: count, dtype: int64
#
# Testing:
# performance
# 0    53
# 1    26
# Name: count, dtype: int64

# %%
numeric_features = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

categorical_features = X.select_dtypes(
    include=["object"]
).columns.tolist()

# %%
numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ]
)

# %%
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        (
            "onehot",
            OneHotEncoder(handle_unknown="ignore")
        )
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            numeric_transformer,
            numeric_features
        ),
        (
            "cat",
            categorical_transformer,
            categorical_features
        )
    ]
)

# %%
logistic_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            LogisticRegression(
                max_iter=1000,
                random_state=42
            )
        )
    ]
)

# %%
random_forest_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            RandomForestClassifier(
                n_estimators=300,
                random_state=42
            )
        )
    ]
)

# %%
xgb_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            XGBClassifier(
                n_estimators=300,
                max_depth=4,
                learning_rate=0.05,
                random_state=42,
                eval_metric="logloss"
            )
        )
    ]
)

# %%
logistic_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=42))])

# %%
random_forest_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('model',
#                  RandomForestClassifier(n_estimators=300, random_state=42))])

# %%
xgb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_freq...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
print("Unique labels:", sorted(y.unique()))
print("Class 0 = Good")
print("Class 1 = At Risk")
# Out:
# Unique labels: [0, 1]
# Class 0 = Good
# Class 1 = At Risk

# %%
print(
    classification_report(
        y_test,
        xgb_pipeline.predict(X_test),
        target_names=["Good", "At Risk"]
    )
)
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.75      0.85      0.80        53
#      At Risk       0.58      0.42      0.49        26
#
#     accuracy                           0.71        79
#    macro avg       0.66      0.64      0.64        79
# weighted avg       0.69      0.71      0.70        79

# %%
df["performance"] = (df["G3"] < 10).astype(int)

# %%
y.value_counts()
# Out:
# performance
# 0    265
# 1    130
# Name: count, dtype: int64

# %%
final_comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Dummy Baseline       0.670886   0.670886  1.000000  0.803030  0.500000
# Logistic Regression  0.696203   0.571429  0.307692  0.400000  0.714804
# Random Forest        0.708861   0.615385  0.307692  0.410256  0.694485
# Original XGBoost     0.708861   0.578947  0.423077  0.488889  0.702467
# Tuned XGBoost        0.759494   0.684211  0.500000  0.577778  0.743832

# %%
print(
    classification_report(
        y_test,
        best_xgb_model.predict(X_test),
        target_names=["Good", "At Risk"]
    )
)
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.78      0.89      0.83        53
#      At Risk       0.68      0.50      0.58        26
#
#     accuracy                           0.76        79
#    macro avg       0.73      0.69      0.70        79
# weighted avg       0.75      0.76      0.75        79

# %%
from sklearn.dummy import DummyClassifier

dummy_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            DummyClassifier(
                strategy="most_frequent"
            )
        )
    ]
)

dummy_model.fit(X_train, y_train)

dummy_results = evaluate_model(
    dummy_model,
    X_test,
    y_test
)

dummy_results
# Out:
# c:\Users\Hardik Master\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# {'Accuracy': 0.6708860759493671,
#  'Precision': 0.0,
#  'Recall': 0.0,
#  'F1': 0.0,
#  'ROC-AUC': 0.5}

# %%
print("Target mapping:")
print("0 = Good")
print("1 = At Risk")

print("\nTarget distribution:")
print(y.value_counts())

print("\nDummy:")
print(dummy_results)

print("\nTuned XGBoost:")
print(tuned_results)
# Out:
# Target mapping:
# 0 = Good
# 1 = At Risk
#
# Target distribution:
# performance
# 0    265
# 1    130
# Name: count, dtype: int64
#
# Dummy:
# {'Accuracy': 0.6708860759493671, 'Precision': 0.0, 'Recall': 0.0, 'F1': 0.0, 'ROC-AUC': 0.5}
#
# Tuned XGBoost:
# {'Accuracy': 0.759493670886076, 'Precision': 0.6842105263157895, 'Recall': 0.5, 'F1': 0.5777777777777777, 'ROC-AUC': 0.7438316400580551}

# %%
final_comparison = pd.DataFrame(
    [
        dummy_results,
        logistic_results,
        rf_results,
        xgb_results,
        tuned_results
    ],
    index=[
        "Dummy Baseline",
        "Logistic Regression",
        "Random Forest",
        "Original XGBoost",
        "Tuned XGBoost"
    ]
)

final_comparison
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Dummy Baseline       0.670886   0.000000  0.000000  0.000000  0.500000
# Logistic Regression  0.696203   0.571429  0.307692  0.400000  0.714804
# Random Forest        0.708861   0.615385  0.307692  0.410256  0.694485
# Original XGBoost     0.708861   0.578947  0.423077  0.488889  0.702467
# Tuned XGBoost        0.759494   0.684211  0.500000  0.577778  0.743832

# %%
import joblib

# %%
best_xgb_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_freq...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
joblib.dump(
    best_xgb_model,
    "../models/student_performance_model.joblib"
)
# Out:
# ['../models/student_performance_model.joblib']

# %%
import os

model_path = "../models/student_performance_model.joblib"

print(os.path.exists(model_path))
# Out:
# True

# %%
print(
    os.path.getsize(model_path) / (1024 * 1024),
    "MB"
)
# Out:
# 0.36997413635253906 MB

# %%
loaded_model = joblib.load(
    "../models/student_performance_model.joblib"
)

# %%
print(loaded_model)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_freq...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
original_predictions = best_xgb_model.predict(X_test)

# %%
loaded_predictions = loaded_model.predict(X_test)

# %%
import numpy as np

print(
    np.array_equal(
        original_predictions,
        loaded_predictions
    )
)
# Out:
# True

# %%
original_probabilities = (
    best_xgb_model.predict_proba(X_test)[:, 1]
)

loaded_probabilities = (
    loaded_model.predict_proba(X_test)[:, 1]
)

# %%
np.allclose(
    original_probabilities,
    loaded_probabilities
)
# Out:
# True

# %%
sample_student = X_test.iloc[[0]]

# %%
X_test.iloc[[0]]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob      Fjob  ...  \
# 383     MS   M   19       R     GT3       T     1     1  other  services  ...
#
#     higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 383    yes       no        no       4         3     2    1    3      5
#
#     absences
# 383        0
#
# [1 rows x 30 columns]

# %%
prediction = loaded_model.predict(
    sample_student
)

probability = loaded_model.predict_proba(
    sample_student
)

# %%
print("Prediction:", prediction)
print("Probabilities:", probability)
# Out:
# Prediction: [1]
# Probabilities: [[0.23411977 0.7658802 ]]

# %%
def predict_student(model, student_data):

    prediction = model.predict(student_data)[0]

    probability = model.predict_proba(
        student_data
    )[0][1]

    if prediction == 1:
        label = "At Risk"
    else:
        label = "Good"

    return {
        "prediction": int(prediction),
        "label": label,
        "at_risk_probability": float(probability)
    }

# %%
result = predict_student(
    loaded_model,
    sample_student
)

print(result)
# Out:
# {'prediction': 1, 'label': 'At Risk', 'at_risk_probability': 0.7658802270889282}

# %%
joblib.dump(
    best_xgb_model,
    "../models/student_performance_model_v1.joblib"
)
# Out:
# ['../models/student_performance_model_v1.joblib']

# %%
import joblib
import numpy as np
import os

# 1. Save
model_path = "../models/student_performance_model.joblib"

joblib.dump(
    best_xgb_model,
    model_path
)

print("Model saved:", os.path.exists(model_path))

# 2. Load
loaded_model = joblib.load(model_path)

print("Model loaded successfully")

# 3. Compare predictions
original_predictions = best_xgb_model.predict(X_test)
loaded_predictions = loaded_model.predict(X_test)

print(
    "Predictions identical:",
    np.array_equal(
        original_predictions,
        loaded_predictions
    )
)

# 4. Compare probabilities
original_probabilities = (
    best_xgb_model.predict_proba(X_test)[:, 1]
)

loaded_probabilities = (
    loaded_model.predict_proba(X_test)[:, 1]
)

print(
    "Probabilities identical:",
    np.allclose(
        original_probabilities,
        loaded_probabilities
    )
)
# Out:
# Model saved: True
# Model loaded successfully
# Predictions identical: True
# Probabilities identical: True
